# %%
import requests
import pandas as pd

# %%
# URL API
url = "https://datagov.mot.go.th/api/3/action/datastore_search"
# resource_id ที่ต้องการ
resource_id = "a139ab23-602f-4c0d-8789-4d230bcdf33d"

# %%
params = {
    "resource_id": resource_id,
    "q": "2025-09",
    "limit": 5000
}

# ส่ง request
response = requests.get(url, params=params)
data = response.json()

# ตรวจสอบผลลัพธ์
if response.status_code == 200 and data["success"]:
    records = data["result"]["records"]
    
    # สร้าง DataFrame เฉพาะคอลัมน์ที่สนใจ
    df = pd.DataFrame(records)[[
        "_id", 
        "รูปแบบการเดินทาง", 
        "วัตถุประสงค์", 
        "สาธารณะ/ส่วนบุคคล", 
        "หน่วยงาน", 
        "ยานพาหนะ/ท่า", 
        "วันที่", 
        "หน่วย", 
        "ปริมาณ"
    ]]
    
    # กรองให้แน่ใจว่าเป็นเดือน 2025-09
    df = df[df["วันที่"].str.startswith("2025-09")]
    
    # แปลงเป็น datetime เพื่อ sort
    df["วันที่"] = pd.to_datetime(df["วันที่"], errors="coerce")
    df = df.sort_values("วันที่").reset_index(drop=True)
    
    print(df.head(10))  # แสดงตัวอย่าง 10 แถวแรก
    print(f"\nจำนวนข้อมูลทั้งหมด: {len(df)} แถว")
else:
    print("ไม่สามารถดึงข้อมูลได้:", response.text)
# Out:
#      _id รูปแบบการเดินทาง              วัตถุประสงค์ สาธารณะ/ส่วนบุคคล  \
# 0  10450           ทางถนน  การเดินทางระหว่างจังหวัด           สาธารณะ
# 1  10474         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 2  10475         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 3  10476         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 4  10477         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 5  10478         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 6  10479           ทางถนน   การเดินทางระหว่างประเทศ           สาธารณะ
# 7  10480           ทางถนน   การเดินทางระหว่างประเทศ           สาธารณะ
# 8  10482           ทางราง   การเดินทางระหว่างประเทศ           สาธารณะ
# 9  10473         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
#
#   หน่วยงาน             ยานพาหนะ/ท่า     วันที่ หน่วย   ปริมาณ
# 0     บขส.       รถ บขส. และ รถร่วม 2025-09-01    คน  82876.0
# 1     ทอท.      ท่าอากาศยานดอนเมือง 2025-09-01    คน  23843.0
# 2     ทอท.  ท่าอากาศอื่น ๆ ของ ทอท. 2025-09-01    คน  19988.0
# 3      ทย.       ท่าอากาศยานภูมิภาค 2025-09-01    คน  16007.0
# 4     กพท.      ท่าอากาศยานอู่ตะเภา 2025-09-01    คน    113.0
# 5     กพท.          ท่าอากาศยานสมุย 2025-09-01    คน   3372.0
# 6     บขส.     รถ บขส. ขาเข้าประเทศ 2025-09-01    คน    575.0
# 7     บขส.      รถ บขส. ขาออกประเทศ 2025-09-01    คน    975.0
# 8     รฟท.         รถไฟ ขาออกประเทศ 2025-09-01    คน    454.0
# 9     ทอท.    ท่าอากาศยานสุวรรณภูมิ 2025-09-01    คน  13803.0
#
# จำนวนข้อมูลทั้งหมด: 1290 แถว

# %%
df[df['ยานพาหนะ/ท่า'] == 'รถไฟฟ้าสายสีชมพู']
# Out:
#         _id รูปแบบการเดินทาง                    วัตถุประสงค์  \
# 81    10512           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 127   10555           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 150   10598           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 206   10641           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 299   10727           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 340   10770           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 367   10813           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 429   10856           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 503   10942           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 551   10985           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 578   11028           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 624   11071           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 726   11157           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 771   11200           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 796   11243           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 852   11286           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 922   11372           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 988   11415           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 1011  11458           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 1055  11501           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 1102  11544           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 1183  11630           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 1232  11673           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 1266  11716           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
#
#      สาธารณะ/ส่วนบุคคล หน่วยงาน      ยานพาหนะ/ท่า     วันที่ หน่วย   ปริมาณ
# 81             สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-02    คน  75584.0
# 127            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-03    คน  75169.0
# 150            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-04    คน  76050.0
# 206            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-05    คน  86750.0
# 299            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-07    คน  45648.0
# 340            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-08    คน  77407.0
# 367            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-09    คน  75923.0
# 429            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-10    คน  75657.0
# 503            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-12    คน  79498.0
# 551            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-13    คน  49696.0
# 578            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-14    คน  36119.0
# 624            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-15    คน  68081.0
# 726            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-17    คน  63791.0
# 771            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-18    คน  64129.0
# 796            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-19    คน  67017.0
# 852            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-20    คน  44837.0
# 922            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-22    คน  63773.0
# 988            สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-23    คน  63561.0
# 1011           สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-24    คน  64007.0
# 1055           สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-25    คน  65585.0
# 1102           สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-26    คน  70456.0
# 1183           สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-28    คน  37045.0
# 1232           สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-29    คน  65245.0
# 1266           สาธารณะ     รฟม.  รถไฟฟ้าสายสีชมพู 2025-09-30    คน  67245.0

# %%
pink = df[df['วันที่'] == '2025-09-06']

# %%
pink[pink['ยานพาหนะ/ท่า'] == 'รถไฟฟ้าสายสีชมพูู']
# Out:
#        _id รูปแบบการเดินทาง                    วัตถุประสงค์ สาธารณะ/ส่วนบุคคล  \
# 248  10684           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ           สาธารณะ
#
#     หน่วยงาน       ยานพาหนะ/ท่า     วันที่ หน่วย   ปริมาณ
# 248     รฟม.  รถไฟฟ้าสายสีชมพูู 2025-09-06    คน  54775.0

# %%
check = pd.read_csv('checkpoint.csv')
